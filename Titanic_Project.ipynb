# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r'D:\spyder\titanic dataset.csv')
dataset.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del dataset["Name"]
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del dataset["Ticket"]
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del dataset["Fare"]
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
del dataset['Cabin']
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
def getNumber(str):
    if str =="male":
        return 1
    else:
        return 2
dataset["Gender"]=dataset["Sex"].apply(getNumber)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
del dataset["Sex"]
dataset.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
meanS= dataset[dataset.Survived==1].Age.mean()
meanS
# Out:
# np.float64(28.343689655172415)

# %%
dataset["age"]=np.where(pd.isnull(dataset.Age) & dataset["Survived"]==1  ,meanS, dataset["Age"])
dataset.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age            125
# dtype: int64

# %%
meanNS=dataset[dataset.Survived==0].Age.mean()
meanNS
# Out:
# np.float64(30.62617924528302)

# %%
dataset.age.fillna(meanNS,inplace=True)
dataset.head()
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\2656476728.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset.age.fillna(meanNS,inplace=True)
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# ...

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
del dataset['Age']
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
survivedQ = dataset[dataset.Embarked == 'Q'][dataset.Survived == 1].shape[0]
survivedC = dataset[dataset.Embarked == 'C'][dataset.Survived == 1].shape[0]
survivedS = dataset[dataset.Embarked == 'S'][dataset.Survived == 1].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 30
# 93
# 217
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\1122364120.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ = dataset[dataset.Embarked == 'Q'][dataset.Survived == 1].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\1122364120.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC = dataset[dataset.Embarked == 'C'][dataset.Survived == 1].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\1122364120.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS = dataset[dataset.Embarked == 'S'][dataset.Survived == 1].shape[0]

# %%
survivedQ = dataset[dataset.Embarked == 'Q'][dataset.Survived == 0].shape[0]
survivedC = dataset[dataset.Embarked == 'C'][dataset.Survived == 0].shape[0]
survivedS = dataset[dataset.Embarked == 'S'][dataset.Survived == 0].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 47
# 75
# 427
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\1011780301.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ = dataset[dataset.Embarked == 'Q'][dataset.Survived == 0].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\1011780301.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC = dataset[dataset.Embarked == 'C'][dataset.Survived == 0].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\1011780301.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS = dataset[dataset.Embarked == 'S'][dataset.Survived == 0].shape[0]

# %%
dataset.dropna(inplace=True)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
dataset.rename(columns={'age':'Age'}, inplace=True)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   Age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
dataset.rename(columns={'Gender':'Sex'}, inplace=True)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %%
def getEmb(str):
    if str=="S":
        return 1
    elif str=='Q':
        return 2
    else:
        return 3
dataset["Embark"]=dataset["Embarked"].apply(getEmb)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del dataset['Embarked']
dataset.rename(columns={'Embark':'Embarked'}, inplace=True)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embarked
# 0            1         0       3      1      0    1  22.0         1
# 1            2         1       1      1      0    2  38.0         3
# 2            3         1       3      0      0    2  26.0         1
# 3            4         1       1      1      0    2  35.0         1
# 4            5         0       3      0      0    1  35.0         1

# %%
import matplotlib.pyplot as plt
from matplotlib import style

males = (dataset['Sex'] == 1).sum()

females = (dataset['Sex'] == 2).sum()
print(males)
print(females)
p = [males, females]
plt.pie(p,
        labels= ['Male', 'Female'],
        colors= ['green', 'yellow'],
        explode= (0.15, 0),
        startangle= 0)
plt.axis('equal')
plt.show()
# Out:
# 577
# 312

# %%
MaleS=dataset[dataset.Sex==1][dataset.Survived==1].shape[0]
print(MaleS)
MaleN=dataset[dataset.Sex==1][dataset.Survived==0].shape[0]
print(MaleN)
FemaleS=dataset[dataset.Sex==2][dataset.Survived==1].shape[0]
print(FemaleS)
FemaleN=dataset[dataset.Sex==2][dataset.Survived==0].shape[0]
print(FemaleN)
# Out:
# 109
# 468
# 231
# 81
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\4153513785.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleS=dataset[dataset.Sex==1][dataset.Survived==1].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\4153513785.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleN=dataset[dataset.Sex==1][dataset.Survived==0].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\4153513785.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleS=dataset[dataset.Sex==2][dataset.Survived==1].shape[0]
# C:\Users\Abid\AppData\Local\Temp\ipykernel_6160\4153513785.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleN=dataset[dataset.Sex==2][dataset.Survived==0].shape[0]

# %%
chart=[MaleS,MaleN,FemaleS,FemaleN]
colors=['lightskyblue','yellowgreen','Yellow','Orange']
labels=["Survived Male","Not Survived Male","Survived Female","Not Survived Female"]
explode=[0,0.05,0,0.1]
plt.pie(chart,labels=labels,colors=colors,explode=explode,startangle=100,counterclock=False,autopct="%.2f%%")
plt.axis("equal")
plt.show()
